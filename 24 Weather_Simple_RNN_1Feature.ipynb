# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# ## Weather dataset (1 feature)

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import seaborn as sns
from collections.abc import Callable
from typing import Literal
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

from utils.helper import fn_plot_tf_hist
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print (fn_plot_tf_hist.__doc__)
# Out:
#     Args:
#         hist_df: a dataframe with following ccolumns
#             column 0: loss
#             column 1: accuracy
#             column 2: val_loss
#             column 3: val_accuracy
#             While plotting columns are accessed by index
#             so that even if the column names are different it will not throw exceptions.

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../input'
outDir = '../output'
modelDir = '../models'
subDir = 'weather'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 20 # number of epochs
BATCH_SIZE = 32
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'medium',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
if not os.path.exists(os.path.join(outDir)):
    os.makedirs(os.path.join(outDir))
    print ('Created {} directory'.format(outDir))

if not os.path.exists(os.path.join(modelDir, subDir)):
    os.makedirs(os.path.join(modelDir, subDir))
    print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %% [markdown]
# ## Read Weather data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'weatherHistory.csv'))
data_df.shape
# Out:
# (96453, 12)

# %%
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %% [markdown]
# ## Taking care of timezone

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'], utc = True)
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary                  datetime
# 0  Partly cloudy throughout the day. 2006-03-31 22:00:00+00:00
# 1  Partly cloudy throughout the day. 2006-03-31 23:00:00+00:00
# 2  Partly cloudy throughout the day. 2006-04-01 00:00:00+00:00
# 3  Partly cloudy throughout the day. 2006-04-01 01:00:00+00:00
# 4  Partly cloudy throughout the day. 2006-04-01 02:00:00+00:00

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
#  12  datetime                  96453 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(8), object(4)
# memory usage: 9.6+ MB

# %%
data_df.describe().T
# Out:
#                             count         mean         std        min  \
# Temperature (C)           96453.0    11.932678    9.551546 -21.822222
# Apparent Temperature (C)  96453.0    10.855029   10.696847 -27.716667
# Humidity                  96453.0     0.734899    0.195473   0.000000
# Wind Speed (km/h)         96453.0    10.810640    6.913571   0.000000
# Wind Bearing (degrees)    96453.0   187.509232  107.383428   0.000000
# Visibility (km)           96453.0    10.347325    4.192123   0.000000
# Loud Cover                96453.0     0.000000    0.000000   0.000000
# Pressure (millibars)      96453.0  1003.235956  116.969906   0.000000
#
#                                   25%        50%          75%          max
# Temperature (C)              4.688889    12.0000    18.838889    39.905556
# Apparent Temperature (C)     2.311111    12.0000    18.838889    39.344444
# Humidity                     0.600000     0.7800     0.890000     1.000000
# Wind Speed (km/h)            5.828200     9.9659    14.135800    63.852600
# Wind Bearing (degrees)     116.000000   180.0000   290.000000   359.000000
# Visibility (km)              8.339800    10.0464    14.812000    16.100000
# Loud Cover                   0.000000     0.0000     0.000000     0.000000
# Pressure (millibars)      1011.900000  1016.4500  1021.090000  1046.380000

# %%
data_df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary', 'datetime'],
#       dtype='object')

# %%
#choosing specific columns
num_cols = ['Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
       'Wind Bearing (degrees)', 'Visibility (km)','Pressure (millibars)', 'Apparent Temperature (C)','Loud Cover']
len(num_cols)
# Out:
# 8

# %%
#histogram
fig, axes = plt.subplots(2,4)
axes = axes.ravel()
for count, col in enumerate (num_cols):
    ax = axes[count]
    sns.histplot(data_df, x = col, ax = ax, bins=20)
plt.tight_layout()

# %%
#boxplot
fig, axes = plt.subplots(2,4)
axes = axes.ravel()
for count, col in enumerate (num_cols):
    ax = axes[count]
    sns.boxplot(data=data_df, y = col, ax = ax)
plt.tight_layout()

# %%
data_df[num_cols].corr()
# Out:
#                           Temperature (C)  Humidity  Wind Speed (km/h)  \
# Temperature (C)                  1.000000 -0.632255           0.008957
# Humidity                        -0.632255  1.000000          -0.224951
# Wind Speed (km/h)                0.008957 -0.224951           1.000000
# Wind Bearing (degrees)           0.029988  0.000735           0.103822
# Visibility (km)                  0.392847 -0.369173           0.100749
# Pressure (millibars)            -0.005447  0.005454          -0.049263
# Apparent Temperature (C)         0.992629 -0.602571          -0.056650
# Loud Cover                            NaN       NaN                NaN
#
#                           Wind Bearing (degrees)  Visibility (km)  \
# Temperature (C)                         0.029988         0.392847
# Humidity                                0.000735        -0.369173
# Wind Speed (km/h)                       0.103822         0.100749
# Wind Bearing (degrees)                  1.000000         0.047594
# Visibility (km)                         0.047594         1.000000
# Pressure (millibars)                   -0.011651         0.059818
# Apparent Temperature (C)                0.029031         0.381718
# Loud Cover                                   NaN              NaN
#
#                           Pressure (millibars)  Apparent Temperature (C)  \
# Temperature (C)                      -0.005447                  0.992629
# Humidity                              0.005454                 -0.602571
# Wind Speed (km/h)                    -0.049263                 -0.056650
# Wind Bearing (degrees)               -0.011651                  0.029031
# Visibility (km)                       0.059818                  0.381718
# Pressure (millibars)                  1.000000                 -0.000219
# Apparent Temperature (C)             -0.000219                  1.000000
# Loud Cover                                 NaN                       NaN
#
#                           Loud Cover
# Temperature (C)                  NaN
# Humidity                         NaN
# Wind Speed (km/h)                NaN
# Wind Bearing (degrees)           NaN
# Visibility (km)                  NaN
# Pressure (millibars)             NaN
# Apparent Temperature (C)         NaN
# Loud Cover                       NaN

# %%
sns.heatmap(data_df[num_cols].corr(), annot=True, cmap = 'flare');

# %%
temp_df = data_df[['datetime','Temperature (C)']]
temp_df = temp_df.sort_values('datetime', axis=0, ascending=True)
temp_df = temp_df.reset_index(drop = True)
temp_df.head()
# Out:
#                    datetime  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
data_df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary', 'datetime'],
#       dtype='object')

# %%
temp_df = temp_df.rename({'Temperature (C)': 'temp'}, axis=1)
temp_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
temp_df.plot(x = 'datetime', y='temp', style='.');

# %%
h_units = 100      # hidden units 
input_shape=(1, 10000)

model = tf.keras.Sequential()
model.add(tf.keras.layers.SimpleRNN(
    units= h_units,
    input_shape=input_shape,
    activation= 'tanh'))
model.add(tf.keras.layers.Dense(1, activation='linear'))
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
len(model.get_weights())
# Out:
# 5

# %%
wax = model.get_weights()[0].shape  #weight of x 
waa = model.get_weights()[1].shape  #contextual info matrix
baa = model.get_weights()[2].shape  #biases
way = model.get_weights()[3].shape  #weights of y / output
bay = model.get_weights()[4].shape  #bias of output 

wax, waa, baa, way, bay
# Out:
# ((10000, 100), (100, 100), (100,), (100, 1), (1,))

# %%
temp_df.head(30)
# Out:
#                     datetime      temp
# 0  2005-12-31 23:00:00+00:00  0.577778
# 1  2006-01-01 00:00:00+00:00  1.161111
# 2  2006-01-01 01:00:00+00:00  1.666667
# 3  2006-01-01 02:00:00+00:00  1.711111
# 4  2006-01-01 03:00:00+00:00  1.183333
# 5  2006-01-01 04:00:00+00:00  1.205556
# 6  2006-01-01 05:00:00+00:00  2.222222
# 7  2006-01-01 06:00:00+00:00  2.072222
# 8  2006-01-01 07:00:00+00:00  2.200000
# 9  2006-01-01 08:00:00+00:00  2.733333
# 10 2006-01-01 09:00:00+00:00  2.788889
# 11 2006-01-01 10:00:00+00:00  3.822222
# 12 2006-01-01 11:00:00+00:00  4.911111
# 13 2006-01-01 12:00:00+00:00  6.205556
# 14 2006-01-01 13:00:00+00:00  7.438889
# 15 2006-01-01 14:00:00+00:00  6.950000
# 16 2006-01-01 15:00:00+00:00  5.972222
# 17 2006-01-01 16:00:00+00:00  5.905556
# 18 2006-01-01 17:00:00+00:00  4.955556
# 19 2006-01-01 18:00:00+00:00  5.472222
# 20 2006-01-01 19:00:00+00:00  5.972222
# 21 2006-01-01 20:00:00+00:00  4.933333
# 22 2006-01-01 21:00:00+00:00  5.472222
# 23 2006-01-01 22:00:00+00:00  5.422222
# 24 2006-01-01 23:00:00+00:00  5.422222
# 25 2006-01-02 00:00:00+00:00  2.350000
# 26 2006-01-02 01:00:00+00:00  5.422222
# 27 2006-01-02 02:00:00+00:00  5.905556
# 28 2006-01-02 03:00:00+00:00  5.966667
# 29 2006-01-02 04:00:00+00:00  5.950000

# %%
time_step = 24
#creating index
y_idx = np.arange(time_step, temp_df.shape[0], time_step)
y_idx.shape

y_df = temp_df.iloc[y_idx]
y_df.head()
# Out:
#                      datetime      temp
# 24  2006-01-01 23:00:00+00:00  5.422222
# 48  2006-01-02 23:00:00+00:00  1.694444
# 72  2006-01-03 23:00:00+00:00  2.200000
# 96  2006-01-04 23:00:00+00:00  1.666667
# 120 2006-01-05 23:00:00+00:00  1.805556

# %%
y_df.shape
# Out:
# (4018, 2)

# %%
y_df.shape[0]*time_step
# Out:
# 96432

# %%
X_df = temp_df.iloc[range(len(y_df)*time_step)]
X_df.shape
# Out:
# (96432, 2)

# %%
X = np.reshape(X_df['temp'].to_numpy(), 
               (y_df.shape[0], time_step))
X = X[:, :23]
X.shape
# Out:
# (4018, 23)

# %% [markdown]
# ### Input Shape expected = '[batch, timestep, feature]'

# %%
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
X.shape
# Out:
# (4018, 23, 1)

# %%
split = int(y_df.shape[0] * (1-TEST_SIZE))
X_train = X[:split]
X_test = X[split:]

y_train = y_df['temp'].to_numpy()[:split]
y_test = y_df['temp'].to_numpy()[split:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3214, 23, 1), (804, 23, 1), (3214,), (804,))

# %%
#model

h_units = 256    # hidden units   
input_shape=(time_step -1, 1)

model = tf.keras.Sequential()
model.add(tf.keras.layers.SimpleRNN(
    units= h_units,
    input_shape=input_shape,
    activation= 'tanh'))

model.add(tf.keras.layers.Dense(1, activation='linear'))

model.compile(loss = 'mean_squared_error', metrics = [tf.keras.metrics.RootMeanSquaredError()], optimizer = 'adam')
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 256)               66048
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 66305 (259.00 KB)
# Trainable params: 66305 (259.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, 
                   epochs = EPOCHS, 
                   batch_size = BATCH_SIZE,
                   validation_data = [X_test, y_test],
                   verbose = 2)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 101/101 - 4s - loss: 10.2712 - root_mean_squared_error: 3.2049 - val_loss: 1.1617 - val_root_mean_squared_error: 1.0778 - 4s/epoch - 39ms/step
# Epoch 2/20
# 101/101 - 2s - loss: 1.7768 - root_mean_squared_error: 1.3330 - val_loss: 0.8475 - val_root_mean_squared_error: 0.9206 - 2s/epoch - 20ms/step
# Epoch 3/20
# 101/101 - 2s - loss: 1.6060 - root_mean_squared_error: 1.2673 - val_loss: 0.8966 - val_root_mean_squared_error: 0.9469 - 2s/epoch - 21ms/step
# Epoch 4/20
# 101/101 - 2s - loss: 1.2704 - root_mean_squared_error: 1.1271 - val_loss: 0.8865 - val_root_mean_squared_error: 0.9415 - 2s/epoch - 20ms/step
# Epoch 5/20
# 101/101 - 2s - loss: 1.1482 - root_mean_squared_error: 1.0715 - val_loss: 0.7252 - val_root_mean_squared_error: 0.8516 - 2s/epoch - 20ms/step
# Epoch 6/20
# 101/101 - 2s - loss: 1.1207 - root_mean_squared_error: 1.0586 - val_loss: 0.8117 - val_root_mean_squared_error: 0.9010 - 2s/epoch - 17ms/step
# Epoch 7/20
# 101/101 - 2s - loss: 1.0941 - root_mean_squared_error: 1.0460 - val_loss: 0.6984 - val_root_mean_squared_error: 0.8357 - 2s/epoch - 19ms/step
# Epoch 8/20
# 101/101 - 2s - loss: 1.0818 - root_mean_squared_error: 1.0401 - val_loss: 0.8228 - val_root_mean_squared_error: 0.9071 - 2s/epoch - 20ms/step
# Epoch 9/20
# 101/101 - 2s - loss: 1.2102 - root_mean_squared_error: 1.1001 - val_loss: 1.4046 - val_root_mean_squared_error: 1.1852 - 2s/epoch - 21ms/step
# Epoch 10/20
# 101/101 - 2s - loss: 1.1516 - root_mean_squared_error: 1.0731 - val_loss: 0.8418 - val_root_mean_squared_error: 0.9175 - 2s/epoch - 21ms/step
# Epoch 11/20
# 101/101 - 2s - loss: 1.0850 - root_mean_squared_error: 1.0416 - val_loss: 0.7108 - val_root_mean_squared_error: 0.8431 - 2s/epoch - 20ms/step
# Epoch 12/20
# 101/101 - 2s - loss: 1.0845 - root_mean_squared_error: 1.0414 - val_loss: 0.6854 - val_root_mean_squared_error: 0.8279 - 2s/epoch - 20ms/step
# Epoch 13/20
# 101/101 - 2s - loss: 1.0504 - root_mean_squared_error: 1.0249 - val_loss: 0.6712 - val_root_mean_squared_error: 0.8193 - 2s/epoch - 20ms/step
# Epoch 14/20
# 101/101 - 2s - loss: 1.0810 - root_mean_squared_error: 1.0397 - val_loss: 0.7304 - val_root_mean_squared_error: 0.8546 - 2s/epoch - 18ms/step
# Epoch 15/20
# 101/101 - 2s - loss: 1.0587 - root_mean_squared_error: 1.0289 - val_loss: 0.7608 - val_root_mean_squared_error: 0.8723 - 2s/epoch - 20ms/step
# Epoch 16/20
# 101/101 - 2s - loss: 1.0825 - root_mean_squared_error: 1.0404 - val_loss: 0.6963 - val_root_mean_squared_error: 0.8344 - 2s/epoch - 20ms/step
# Epoch 17/20
# 101/101 - 2s - loss: 1.0515 - root_mean_squared_error: 1.0254 - val_loss: 1.1443 - val_root_mean_squared_error: 1.0697 - 2s/epoch - 20ms/step
# Epoch 18/20
# 101/101 - 2s - loss: 1.0682 - root_mean_squared_error: 1.0336 - val_loss: 0.6621 - val_root_mean_squared_error: 0.8137 - 2s/epoch - 20ms/step
# Epoch 19/20
# 101/101 - 2s - loss: 1.0608 - root_mean_squared_error: 1.0300 - val_loss: 0.7842 - val_root_mean_squared_error: 0.8856 - 2s/epoch - 20ms/step
# Epoch 20/20
# 101/101 - 2s - loss: 1.0997 - root_mean_squared_error: 1.0487 - val_loss: 1.0589 - val_root_mean_squared_error: 1.0290 - 2s/epoch - 21ms/step

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
y_pred = np.append(y_train_pred, y_test_pred)

y_pred.shape
# Out:
# 101/101 [==============================] - 1s 8ms/step
# 26/26 [==============================] - 0s 7ms/step
# (4018,)

# %%
res_df = y_df.copy()
res_df['pred'] = y_pred
res_df['datetime'] = res_df['datetime'].dt.date
res_df.head()
# Out:
#        datetime      temp      pred
# 24   2006-01-01  5.422222  4.462867
# 48   2006-01-02  1.694444  1.188269
# 72   2006-01-03  2.200000  1.437851
# 96   2006-01-04  1.666667  1.340787
# 120  2006-01-05  1.805556  1.814583

# %%
fig, ax = plt.subplots(figsize = (30, 15))
res_df[-500:].plot(x = 'datetime', y = ['temp', 'pred'], ax = ax);
