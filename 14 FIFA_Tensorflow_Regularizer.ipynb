# %%
#!/usr/bin/env python`
# -*- coding: utf-8 -*-

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import torch

from collections.abc import Callable
from typing import Literal

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import sys

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix, fn_plot_torch_hist
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print(fn_plot_tf_hist.__doc__)
# Out:
#     Args:
#         hist_df: a dataframe with following ccolumns
#             column 0: loss
#             column 1: accuracy
#             column 2: val_loss
#             column 3: val_accuracy
#             While plotting columns are accessed by index
#             so that even if the column names are different it will not throw exceptions.

# %%
print (fn_plot_confusion_matrix.__doc__)
# Out:
#     Args:
#         y_true: Ground Truth
#         y_pred : Predictions
#         labels : dictonary
#                   {0: 'Goal Keeper',
#                   1: 'Defender',
#                   2: 'Mid-Fielder',
#                   3: 'Forward'}

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../input'
outDir = '../output'
modelDir = './models'
subDir = 'fifa_2019'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 101 # number of epochs
ALPHA = 0.001 # learning rate

BATCH_SIZE = 32
TEST_SIZE = 0.2
REG_LAMBDA = 0.001


# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'medium',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'fifa_2019.csv'))
data_df.shape
# Out:
# (18207, 89)

# %%
#data_df.columns

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
#data_df.head()

# %%
#data_df['Position'].isnull()

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
data_df = data_df[rel_cols]
#data_df.head()

# %%
labels101 = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
features_df = data_df.drop('Position', axis = 1)
labels = data_df['Position']

# %%
data_df['Position'].isnull().sum()
# Out:
# 0

# %%
# splitting in train ans test datasets
X_train, X_test, y_train, y_test = train_test_split(features_df, labels,
                                     stratify=labels,
                                     test_size=TEST_SIZE, 
                                     random_state=RANDOM_STATE )
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14517, 33), (3630, 33), (14517,), (3630,))

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (14517, 33)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %% [markdown]
# # defining model

# %%
# 33 -> 23 -> 12 -> 4 -> 4 #diving layers

# %% [markdown]
# # without regularizer

# %%
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape = (33,)),
    tf.keras.layers.Dense(33, activation='relu', kernel_initializer = k_init),
    #tf.keras.layers.ReLU()
    tf.keras.layers.Dense(23, activation='relu', kernel_initializer=k_init),
    tf.keras.layers.Dense(12, activation='relu',  kernel_initializer=k_init),
    tf.keras.layers.Dense(4, activation='relu', kernel_initializer=k_init),
    tf.keras.layers.Dense(4)
])
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.01227756, -0.08197653,  0.21723892, -0.22544809]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    verbose=2
                   )
# Out:
# Epoch 1/101
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 454/454 - 4s - loss: 0.5300 - accuracy: 0.7540 - val_loss: 0.3403 - val_accuracy: 0.8576 - 4s/epoch - 8ms/step
# Epoch 2/101
# 454/454 - 1s - loss: 0.3217 - accuracy: 0.8667 - val_loss: 0.3230 - val_accuracy: 0.8661 - 1s/epoch - 3ms/step
# Epoch 3/101
# 454/454 - 1s - loss: 0.3055 - accuracy: 0.8751 - val_loss: 0.3167 - val_accuracy: 0.8667 - 1s/epoch - 3ms/step
# Epoch 4/101
# 454/454 - 1s - loss: 0.2972 - accuracy: 0.8771 - val_loss: 0.3063 - val_accuracy: 0.8708 - 1s/epoch - 3ms/step
# Epoch 5/101
# 454/454 - 1s - loss: 0.2908 - accuracy: 0.8797 - val_loss: 0.3091 - val_accuracy: 0.8694 - 1s/epoch - 3ms/step
# Epoch 6/101
# 454/454 - 1s - loss: 0.2862 - accuracy: 0.8832 - val_loss: 0.3028 - val_accuracy: 0.8744 - 1s/epoch - 3ms/step
# Epoch 7/101
# 454/454 - 2s - loss: 0.2837 - accuracy: 0.8825 - val_loss: 0.3034 - val_accuracy: 0.8749 - 2s/epoch - 3ms/step
# Epoch 8/101
# 454/454 - 1s - loss: 0.2807 - accuracy: 0.8826 - val_loss: 0.3064 - val_accuracy: 0.8744 - 1s/epoch - 3ms/step
# Epoch 9/101
# 454/454 - 1s - loss: 0.2792 - accuracy: 0.8839 - val_loss: 0.3045 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 10/101
# 454/454 - 1s - loss: 0.2773 - accuracy: 0.8863 - val_loss: 0.2990 - val_accuracy: 0.8785 - 1s/epoch - 3ms/step
# Epoch 11/101
# 454/454 - 1s - loss: 0.2756 - accuracy: 0.8874 - val_loss: 0.2990 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 12/101
# 454/454 - 1s - loss: 0.2727 - accuracy: 0.8879 - val_loss: 0.2999 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 13/101
# 454/454 - 2s - loss: 0.2718 - accuracy: 0.8891 - val_loss: 0.2969 - val_accuracy: 0.8796 - 2s/epoch - 4ms/step
# Epoch 14/101
# 454/454 - 2s - loss: 0.2698 - accuracy: 0.8901 - val_loss: 0.2994 - val_accuracy: 0.8791 - 2s/epoch - 3ms/step
# Epoch 15/101
# 454/454 - 1s - loss: 0.2681 - accuracy: 0.8901 - val_loss: 0.3068 - val_accuracy: 0.8738 - 1s/epoch - 3ms/step
# Epoch 16/101
# 454/454 - 1s - loss: 0.2672 - accuracy: 0.8910 - val_loss: 0.3006 - val_accuracy: 0.8782 - 1s/epoch - 3ms/step
# Epoch 17/101
# 454/454 - 1s - loss: 0.2646 - accuracy: 0.8912 - val_loss: 0.3049 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 18/101
# 454/454 - 1s - loss: 0.2637 - accuracy: 0.8914 - val_loss: 0.2986 - val_accuracy: 0.8791 - 1s/epoch - 3ms/step
# Epoch 19/101
# 454/454 - 1s - loss: 0.2620 - accuracy: 0.8925 - val_loss: 0.2993 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 20/101
# 454/454 - 1s - loss: 0.2610 - accuracy: 0.8930 - val_loss: 0.3036 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 21/101
# 454/454 - 1s - loss: 0.2603 - accuracy: 0.8951 - val_loss: 0.3005 - val_accuracy: 0.8788 - 1s/epoch - 3ms/step
# Epoch 22/101
# 454/454 - 1s - loss: 0.2584 - accuracy: 0.8946 - val_loss: 0.3065 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 23/101
# 454/454 - 1s - loss: 0.2563 - accuracy: 0.8941 - val_loss: 0.3060 - val_accuracy: 0.8744 - 1s/epoch - 3ms/step
# Epoch 24/101
# 454/454 - 1s - loss: 0.2561 - accuracy: 0.8943 - val_loss: 0.3008 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 25/101
# 454/454 - 1s - loss: 0.2560 - accuracy: 0.8954 - val_loss: 0.3057 - val_accuracy: 0.8782 - 1s/epoch - 3ms/step
# Epoch 26/101
# 454/454 - 1s - loss: 0.2547 - accuracy: 0.8963 - val_loss: 0.3013 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 27/101
# 454/454 - 1s - loss: 0.2532 - accuracy: 0.8953 - val_loss: 0.3095 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 28/101
# 454/454 - 2s - loss: 0.2519 - accuracy: 0.8979 - val_loss: 0.3060 - val_accuracy: 0.8741 - 2s/epoch - 4ms/step
# Epoch 29/101
# 454/454 - 1s - loss: 0.2508 - accuracy: 0.8995 - val_loss: 0.3073 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 30/101
# 454/454 - 1s - loss: 0.2492 - accuracy: 0.8985 - val_loss: 0.3011 - val_accuracy: 0.8755 - 1s/epoch - 3ms/step
# Epoch 31/101
# 454/454 - 2s - loss: 0.2483 - accuracy: 0.8989 - val_loss: 0.3069 - val_accuracy: 0.8741 - 2s/epoch - 4ms/step
# Epoch 32/101
# 454/454 - 1s - loss: 0.2460 - accuracy: 0.9005 - val_loss: 0.3103 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 33/101
# 454/454 - 1s - loss: 0.2463 - accuracy: 0.8994 - val_loss: 0.3311 - val_accuracy: 0.8634 - 1s/epoch - 3ms/step
# Epoch 34/101
# 454/454 - 2s - loss: 0.2448 - accuracy: 0.9015 - val_loss: 0.3049 - val_accuracy: 0.8741 - 2s/epoch - 3ms/step
# Epoch 35/101
# 454/454 - 1s - loss: 0.2444 - accuracy: 0.9009 - val_loss: 0.3201 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 36/101
# 454/454 - 1s - loss: 0.2421 - accuracy: 0.8996 - val_loss: 0.3092 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 37/101
# 454/454 - 1s - loss: 0.2419 - accuracy: 0.9018 - val_loss: 0.3070 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 38/101
# 454/454 - 2s - loss: 0.2391 - accuracy: 0.9031 - val_loss: 0.3151 - val_accuracy: 0.8705 - 2s/epoch - 3ms/step
# Epoch 39/101
# 454/454 - 1s - loss: 0.2375 - accuracy: 0.9041 - val_loss: 0.3209 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 40/101
# 454/454 - 1s - loss: 0.2370 - accuracy: 0.9045 - val_loss: 0.3131 - val_accuracy: 0.8727 - 1s/epoch - 3ms/step
# Epoch 41/101
# 454/454 - 2s - loss: 0.2385 - accuracy: 0.9031 - val_loss: 0.3124 - val_accuracy: 0.8713 - 2s/epoch - 3ms/step
# Epoch 42/101
# 454/454 - 1s - loss: 0.2342 - accuracy: 0.9050 - val_loss: 0.3134 - val_accuracy: 0.8730 - 1s/epoch - 3ms/step
# Epoch 43/101
# 454/454 - 1s - loss: 0.2340 - accuracy: 0.9058 - val_loss: 0.3160 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 44/101
# 454/454 - 1s - loss: 0.2328 - accuracy: 0.9073 - val_loss: 0.3159 - val_accuracy: 0.8730 - 1s/epoch - 3ms/step
# Epoch 45/101
# 454/454 - 1s - loss: 0.2325 - accuracy: 0.9058 - val_loss: 0.3232 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 46/101
# 454/454 - 1s - loss: 0.2318 - accuracy: 0.9078 - val_loss: 0.3237 - val_accuracy: 0.8727 - 1s/epoch - 3ms/step
# Epoch 47/101
# 454/454 - 1s - loss: 0.2290 - accuracy: 0.9069 - val_loss: 0.3216 - val_accuracy: 0.8760 - 1s/epoch - 3ms/step
# Epoch 48/101
# 454/454 - 1s - loss: 0.2295 - accuracy: 0.9069 - val_loss: 0.3314 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 49/101
# 454/454 - 1s - loss: 0.2297 - accuracy: 0.9079 - val_loss: 0.3186 - val_accuracy: 0.8683 - 1s/epoch - 3ms/step
# Epoch 50/101
# 454/454 - 2s - loss: 0.2268 - accuracy: 0.9075 - val_loss: 0.3209 - val_accuracy: 0.8694 - 2s/epoch - 3ms/step
# Epoch 51/101
# 454/454 - 1s - loss: 0.2279 - accuracy: 0.9080 - val_loss: 0.3253 - val_accuracy: 0.8708 - 1s/epoch - 3ms/step
# Epoch 52/101
# 454/454 - 1s - loss: 0.2268 - accuracy: 0.9084 - val_loss: 0.3339 - val_accuracy: 0.8702 - 1s/epoch - 3ms/step
# Epoch 53/101
# 454/454 - 1s - loss: 0.2250 - accuracy: 0.9086 - val_loss: 0.3382 - val_accuracy: 0.8716 - 1s/epoch - 3ms/step
# Epoch 54/101
# 454/454 - 1s - loss: 0.2234 - accuracy: 0.9108 - val_loss: 0.3324 - val_accuracy: 0.8727 - 1s/epoch - 3ms/step
# Epoch 55/101
# 454/454 - 1s - loss: 0.2228 - accuracy: 0.9102 - val_loss: 0.3271 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 56/101
# 454/454 - 1s - loss: 0.2224 - accuracy: 0.9104 - val_loss: 0.3325 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 57/101
# 454/454 - 1s - loss: 0.2209 - accuracy: 0.9106 - val_loss: 0.3394 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 58/101
# 454/454 - 1s - loss: 0.2195 - accuracy: 0.9101 - val_loss: 0.3414 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 59/101
# 454/454 - 1s - loss: 0.2201 - accuracy: 0.9091 - val_loss: 0.3386 - val_accuracy: 0.8711 - 1s/epoch - 3ms/step
# Epoch 60/101
# 454/454 - 1s - loss: 0.2181 - accuracy: 0.9115 - val_loss: 0.3361 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 61/101
# 454/454 - 1s - loss: 0.2175 - accuracy: 0.9111 - val_loss: 0.3474 - val_accuracy: 0.8700 - 1s/epoch - 3ms/step
# Epoch 62/101
# 454/454 - 1s - loss: 0.2171 - accuracy: 0.9132 - val_loss: 0.3416 - val_accuracy: 0.8694 - 1s/epoch - 3ms/step
# Epoch 63/101
# 454/454 - 1s - loss: 0.2167 - accuracy: 0.9122 - val_loss: 0.3379 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 64/101
# 454/454 - 1s - loss: 0.2151 - accuracy: 0.9131 - val_loss: 0.3368 - val_accuracy: 0.8691 - 1s/epoch - 3ms/step
# Epoch 65/101
# 454/454 - 1s - loss: 0.2145 - accuracy: 0.9138 - val_loss: 0.3448 - val_accuracy: 0.8675 - 1s/epoch - 3ms/step
# Epoch 66/101
# 454/454 - 1s - loss: 0.2119 - accuracy: 0.9139 - val_loss: 0.3469 - val_accuracy: 0.8661 - 1s/epoch - 3ms/step
# Epoch 67/101
# 454/454 - 1s - loss: 0.2127 - accuracy: 0.9144 - val_loss: 0.3459 - val_accuracy: 0.8675 - 1s/epoch - 3ms/step
# Epoch 68/101
# 454/454 - 1s - loss: 0.2116 - accuracy: 0.9130 - val_loss: 0.3467 - val_accuracy: 0.8617 - 1s/epoch - 3ms/step
# Epoch 69/101
# 454/454 - 1s - loss: 0.2108 - accuracy: 0.9144 - val_loss: 0.3532 - val_accuracy: 0.8669 - 1s/epoch - 3ms/step
# Epoch 70/101
# 454/454 - 1s - loss: 0.2091 - accuracy: 0.9169 - val_loss: 0.3499 - val_accuracy: 0.8656 - 1s/epoch - 3ms/step
# Epoch 71/101
# 454/454 - 1s - loss: 0.2087 - accuracy: 0.9153 - val_loss: 0.3483 - val_accuracy: 0.8702 - 1s/epoch - 3ms/step
# Epoch 72/101
# 454/454 - 1s - loss: 0.2090 - accuracy: 0.9167 - val_loss: 0.3475 - val_accuracy: 0.8631 - 1s/epoch - 3ms/step
# Epoch 73/101
# 454/454 - 1s - loss: 0.2083 - accuracy: 0.9149 - val_loss: 0.3533 - val_accuracy: 0.8595 - 1s/epoch - 3ms/step
# Epoch 74/101
# 454/454 - 1s - loss: 0.2055 - accuracy: 0.9168 - val_loss: 0.3583 - val_accuracy: 0.8733 - 1s/epoch - 3ms/step
# Epoch 75/101
# 454/454 - 1s - loss: 0.2069 - accuracy: 0.9168 - val_loss: 0.3626 - val_accuracy: 0.8598 - 1s/epoch - 3ms/step
# Epoch 76/101
# 454/454 - 1s - loss: 0.2054 - accuracy: 0.9180 - val_loss: 0.3537 - val_accuracy: 0.8645 - 1s/epoch - 3ms/step
# Epoch 77/101
# 454/454 - 1s - loss: 0.2048 - accuracy: 0.9171 - val_loss: 0.3551 - val_accuracy: 0.8664 - 1s/epoch - 3ms/step
# Epoch 78/101
# 454/454 - 1s - loss: 0.2044 - accuracy: 0.9177 - val_loss: 0.3634 - val_accuracy: 0.8669 - 1s/epoch - 3ms/step
# Epoch 79/101
# 454/454 - 1s - loss: 0.2027 - accuracy: 0.9186 - val_loss: 0.3605 - val_accuracy: 0.8667 - 1s/epoch - 3ms/step
# Epoch 80/101
# 454/454 - 1s - loss: 0.2024 - accuracy: 0.9185 - val_loss: 0.3532 - val_accuracy: 0.8661 - 1s/epoch - 3ms/step
# Epoch 81/101
# 454/454 - 1s - loss: 0.2032 - accuracy: 0.9175 - val_loss: 0.3795 - val_accuracy: 0.8614 - 1s/epoch - 3ms/step
# Epoch 82/101
# 454/454 - 1s - loss: 0.2000 - accuracy: 0.9193 - val_loss: 0.3713 - val_accuracy: 0.8623 - 1s/epoch - 3ms/step
# Epoch 83/101
# 454/454 - 1s - loss: 0.1998 - accuracy: 0.9201 - val_loss: 0.3646 - val_accuracy: 0.8700 - 1s/epoch - 3ms/step
# Epoch 84/101
# 454/454 - 2s - loss: 0.1990 - accuracy: 0.9226 - val_loss: 0.3902 - val_accuracy: 0.8612 - 2s/epoch - 3ms/step
# Epoch 85/101
# 454/454 - 1s - loss: 0.1985 - accuracy: 0.9195 - val_loss: 0.3681 - val_accuracy: 0.8631 - 1s/epoch - 3ms/step
# Epoch 86/101
# 454/454 - 1s - loss: 0.1987 - accuracy: 0.9208 - val_loss: 0.3643 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 87/101
# 454/454 - 1s - loss: 0.1965 - accuracy: 0.9216 - val_loss: 0.3748 - val_accuracy: 0.8642 - 1s/epoch - 3ms/step
# Epoch 88/101
# 454/454 - 1s - loss: 0.1959 - accuracy: 0.9216 - val_loss: 0.3659 - val_accuracy: 0.8667 - 1s/epoch - 3ms/step
# Epoch 89/101
# 454/454 - 1s - loss: 0.1950 - accuracy: 0.9222 - val_loss: 0.3726 - val_accuracy: 0.8612 - 1s/epoch - 3ms/step
# Epoch 90/101
# 454/454 - 2s - loss: 0.1956 - accuracy: 0.9228 - val_loss: 0.3857 - val_accuracy: 0.8634 - 2s/epoch - 4ms/step
# Epoch 91/101
# 454/454 - 1s - loss: 0.1941 - accuracy: 0.9198 - val_loss: 0.3887 - val_accuracy: 0.8639 - 1s/epoch - 3ms/step
# Epoch 92/101
# 454/454 - 1s - loss: 0.1936 - accuracy: 0.9243 - val_loss: 0.3861 - val_accuracy: 0.8598 - 1s/epoch - 3ms/step
# Epoch 93/101
# 454/454 - 1s - loss: 0.1937 - accuracy: 0.9216 - val_loss: 0.3822 - val_accuracy: 0.8592 - 1s/epoch - 3ms/step
# Epoch 94/101
# 454/454 - 1s - loss: 0.1923 - accuracy: 0.9236 - val_loss: 0.3874 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 95/101
# 454/454 - 1s - loss: 0.1919 - accuracy: 0.9233 - val_loss: 0.3838 - val_accuracy: 0.8689 - 1s/epoch - 3ms/step
# Epoch 96/101
# 454/454 - 1s - loss: 0.1940 - accuracy: 0.9231 - val_loss: 0.3871 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 97/101
# 454/454 - 1s - loss: 0.1899 - accuracy: 0.9239 - val_loss: 0.3874 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 98/101
# 454/454 - 2s - loss: 0.1924 - accuracy: 0.9242 - val_loss: 0.3896 - val_accuracy: 0.8579 - 2s/epoch - 4ms/step
# Epoch 99/101
# 454/454 - 1s - loss: 0.1914 - accuracy: 0.9220 - val_loss: 0.4028 - val_accuracy: 0.8664 - 1s/epoch - 3ms/step
# Epoch 100/101
# 454/454 - 1s - loss: 0.1894 - accuracy: 0.9249 - val_loss: 0.4019 - val_accuracy: 0.8650 - 1s/epoch - 3ms/step
# Epoch 101/101
# 454/454 - 1s - loss: 0.1887 - accuracy: 0.9238 - val_loss: 0.3896 - val_accuracy: 0.8634 - 1s/epoch - 3ms/step

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.529981  0.754013  0.340336      0.857576
# 1  0.321737  0.866708  0.323016      0.866116
# 2  0.305525  0.875112  0.316743      0.866667
# 3  0.297211  0.877110  0.306326      0.870799
# 4  0.290819  0.879658  0.309051      0.869421

# %%
fn_plot_tf_hist(loss_df)

# %% [markdown]
# # with regularizers

# %%
#initializer
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)
#regularizer
k_reg = tf.keras.regularizers.L2(l2=REG_LAMBDA)

model = tf.keras.Sequential([
      #input layer
    tf.keras.layers.InputLayer(input_shape = (33,)),
    
    #set 1
    tf.keras.layers.Dense(33, activation='relu', 
                          kernel_initializer = k_init, 
                          kernel_regularizer=k_reg),
    #tf.keras.layers.ReLU()

    #set 2
    tf.keras.layers.Dense(23, activation='relu', 
                          kernel_initializer=k_init, 
                          kernel_regularizer=k_reg),
    #set 3
    tf.keras.layers.Dense(12, activation='relu', 
                          kernel_initializer=k_init, 
                          kernel_regularizer=k_reg),
    #set 4
    tf.keras.layers.Dense(4, activation='relu', 
                          kernel_initializer=k_init, 
                          kernel_regularizer=k_reg),

    #output layer
    tf.keras.layers.Dense(4)
])

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[-0.02738495,  0.30430323,  0.2071535 , -0.18463118]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    verbose=2
                   )
# Out:
# Epoch 1/101
# 454/454 - 3s - loss: 0.6561 - accuracy: 0.7571 - val_loss: 0.5067 - val_accuracy: 0.8402 - 3s/epoch - 7ms/step
# Epoch 2/101
# 454/454 - 1s - loss: 0.4627 - accuracy: 0.8535 - val_loss: 0.4274 - val_accuracy: 0.8683 - 1s/epoch - 3ms/step
# Epoch 3/101
# 454/454 - 1s - loss: 0.4001 - accuracy: 0.8710 - val_loss: 0.3863 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 4/101
# 454/454 - 1s - loss: 0.3680 - accuracy: 0.8776 - val_loss: 0.3660 - val_accuracy: 0.8716 - 1s/epoch - 3ms/step
# Epoch 5/101
# 454/454 - 1s - loss: 0.3496 - accuracy: 0.8801 - val_loss: 0.3582 - val_accuracy: 0.8647 - 1s/epoch - 3ms/step
# Epoch 6/101
# 454/454 - 1s - loss: 0.3381 - accuracy: 0.8809 - val_loss: 0.3436 - val_accuracy: 0.8727 - 1s/epoch - 3ms/step
# Epoch 7/101
# 454/454 - 1s - loss: 0.3303 - accuracy: 0.8808 - val_loss: 0.3457 - val_accuracy: 0.8702 - 1s/epoch - 3ms/step
# Epoch 8/101
# 454/454 - 1s - loss: 0.3258 - accuracy: 0.8806 - val_loss: 0.3459 - val_accuracy: 0.8738 - 1s/epoch - 3ms/step
# Epoch 9/101
# 454/454 - 1s - loss: 0.3232 - accuracy: 0.8843 - val_loss: 0.3354 - val_accuracy: 0.8716 - 1s/epoch - 3ms/step
# Epoch 10/101
# 454/454 - 2s - loss: 0.3198 - accuracy: 0.8847 - val_loss: 0.3329 - val_accuracy: 0.8774 - 2s/epoch - 3ms/step
# Epoch 11/101
# 454/454 - 1s - loss: 0.3179 - accuracy: 0.8845 - val_loss: 0.3308 - val_accuracy: 0.8719 - 1s/epoch - 3ms/step
# Epoch 12/101
# 454/454 - 1s - loss: 0.3144 - accuracy: 0.8867 - val_loss: 0.3316 - val_accuracy: 0.8752 - 1s/epoch - 3ms/step
# Epoch 13/101
# 454/454 - 2s - loss: 0.3133 - accuracy: 0.8862 - val_loss: 0.3251 - val_accuracy: 0.8804 - 2s/epoch - 3ms/step
# Epoch 14/101
# 454/454 - 1s - loss: 0.3116 - accuracy: 0.8865 - val_loss: 0.3256 - val_accuracy: 0.8802 - 1s/epoch - 3ms/step
# Epoch 15/101
# 454/454 - 1s - loss: 0.3104 - accuracy: 0.8855 - val_loss: 0.3337 - val_accuracy: 0.8719 - 1s/epoch - 3ms/step
# Epoch 16/101
# 454/454 - 1s - loss: 0.3091 - accuracy: 0.8872 - val_loss: 0.3349 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 17/101
# 454/454 - 1s - loss: 0.3067 - accuracy: 0.8865 - val_loss: 0.3356 - val_accuracy: 0.8702 - 1s/epoch - 3ms/step
# Epoch 18/101
# 454/454 - 1s - loss: 0.3051 - accuracy: 0.8876 - val_loss: 0.3244 - val_accuracy: 0.8799 - 1s/epoch - 3ms/step
# Epoch 19/101
# 454/454 - 1s - loss: 0.3047 - accuracy: 0.8880 - val_loss: 0.3272 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 20/101
# 454/454 - 1s - loss: 0.3034 - accuracy: 0.8886 - val_loss: 0.3325 - val_accuracy: 0.8708 - 1s/epoch - 3ms/step
# Epoch 21/101
# 454/454 - 1s - loss: 0.3024 - accuracy: 0.8881 - val_loss: 0.3233 - val_accuracy: 0.8810 - 1s/epoch - 3ms/step
# Epoch 22/101
# 454/454 - 1s - loss: 0.3016 - accuracy: 0.8900 - val_loss: 0.3270 - val_accuracy: 0.8755 - 1s/epoch - 3ms/step
# Epoch 23/101
# 454/454 - 1s - loss: 0.3004 - accuracy: 0.8888 - val_loss: 0.3265 - val_accuracy: 0.8785 - 1s/epoch - 3ms/step
# Epoch 24/101
# 454/454 - 1s - loss: 0.3001 - accuracy: 0.8904 - val_loss: 0.3223 - val_accuracy: 0.8777 - 1s/epoch - 3ms/step
# Epoch 25/101
# 454/454 - 1s - loss: 0.3013 - accuracy: 0.8872 - val_loss: 0.3233 - val_accuracy: 0.8791 - 1s/epoch - 3ms/step
# Epoch 26/101
# 454/454 - 1s - loss: 0.2993 - accuracy: 0.8884 - val_loss: 0.3256 - val_accuracy: 0.8777 - 1s/epoch - 3ms/step
# Epoch 27/101
# 454/454 - 1s - loss: 0.2994 - accuracy: 0.8895 - val_loss: 0.3256 - val_accuracy: 0.8766 - 1s/epoch - 3ms/step
# Epoch 28/101
# 454/454 - 1s - loss: 0.2967 - accuracy: 0.8899 - val_loss: 0.3296 - val_accuracy: 0.8711 - 1s/epoch - 3ms/step
# Epoch 29/101
# 454/454 - 1s - loss: 0.2968 - accuracy: 0.8914 - val_loss: 0.3266 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 30/101
# 454/454 - 1s - loss: 0.2958 - accuracy: 0.8922 - val_loss: 0.3239 - val_accuracy: 0.8766 - 1s/epoch - 3ms/step
# Epoch 31/101
# 454/454 - 1s - loss: 0.2962 - accuracy: 0.8894 - val_loss: 0.3301 - val_accuracy: 0.8747 - 1s/epoch - 3ms/step
# Epoch 32/101
# 454/454 - 1s - loss: 0.2937 - accuracy: 0.8900 - val_loss: 0.3281 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 33/101
# 454/454 - 1s - loss: 0.2941 - accuracy: 0.8915 - val_loss: 0.3446 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 34/101
# 454/454 - 1s - loss: 0.2944 - accuracy: 0.8919 - val_loss: 0.3252 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 35/101
# 454/454 - 1s - loss: 0.2938 - accuracy: 0.8910 - val_loss: 0.3273 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 36/101
# 454/454 - 1s - loss: 0.2931 - accuracy: 0.8911 - val_loss: 0.3259 - val_accuracy: 0.8771 - 1s/epoch - 3ms/step
# Epoch 37/101
# 454/454 - 1s - loss: 0.2931 - accuracy: 0.8901 - val_loss: 0.3246 - val_accuracy: 0.8771 - 1s/epoch - 3ms/step
# Epoch 38/101
# 454/454 - 1s - loss: 0.2901 - accuracy: 0.8945 - val_loss: 0.3329 - val_accuracy: 0.8705 - 1s/epoch - 3ms/step
# Epoch 39/101
# 454/454 - 1s - loss: 0.2905 - accuracy: 0.8933 - val_loss: 0.3352 - val_accuracy: 0.8752 - 1s/epoch - 3ms/step
# Epoch 40/101
# 454/454 - 1s - loss: 0.2902 - accuracy: 0.8934 - val_loss: 0.3229 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 41/101
# 454/454 - 1s - loss: 0.2923 - accuracy: 0.8903 - val_loss: 0.3247 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 42/101
# 454/454 - 1s - loss: 0.2883 - accuracy: 0.8936 - val_loss: 0.3297 - val_accuracy: 0.8736 - 1s/epoch - 3ms/step
# Epoch 43/101
# 454/454 - 1s - loss: 0.2893 - accuracy: 0.8926 - val_loss: 0.3234 - val_accuracy: 0.8771 - 1s/epoch - 3ms/step
# Epoch 44/101
# 454/454 - 1s - loss: 0.2879 - accuracy: 0.8930 - val_loss: 0.3330 - val_accuracy: 0.8658 - 1s/epoch - 3ms/step
# Epoch 45/101
# 454/454 - 1s - loss: 0.2885 - accuracy: 0.8942 - val_loss: 0.3260 - val_accuracy: 0.8793 - 1s/epoch - 3ms/step
# Epoch 46/101
# 454/454 - 1s - loss: 0.2890 - accuracy: 0.8921 - val_loss: 0.3272 - val_accuracy: 0.8769 - 1s/epoch - 3ms/step
# Epoch 47/101
# 454/454 - 1s - loss: 0.2873 - accuracy: 0.8923 - val_loss: 0.3246 - val_accuracy: 0.8780 - 1s/epoch - 3ms/step
# Epoch 48/101
# 454/454 - 2s - loss: 0.2872 - accuracy: 0.8945 - val_loss: 0.3315 - val_accuracy: 0.8713 - 2s/epoch - 3ms/step
# Epoch 49/101
# 454/454 - 1s - loss: 0.2880 - accuracy: 0.8945 - val_loss: 0.3283 - val_accuracy: 0.8733 - 1s/epoch - 3ms/step
# Epoch 50/101
# 454/454 - 2s - loss: 0.2861 - accuracy: 0.8947 - val_loss: 0.3294 - val_accuracy: 0.8733 - 2s/epoch - 3ms/step
# Epoch 51/101
# 454/454 - 1s - loss: 0.2874 - accuracy: 0.8928 - val_loss: 0.3242 - val_accuracy: 0.8752 - 1s/epoch - 3ms/step
# Epoch 52/101
# 454/454 - 1s - loss: 0.2873 - accuracy: 0.8927 - val_loss: 0.3263 - val_accuracy: 0.8760 - 1s/epoch - 3ms/step
# Epoch 53/101
# 454/454 - 1s - loss: 0.2862 - accuracy: 0.8940 - val_loss: 0.3361 - val_accuracy: 0.8719 - 1s/epoch - 3ms/step
# Epoch 54/101
# 454/454 - 1s - loss: 0.2843 - accuracy: 0.8973 - val_loss: 0.3282 - val_accuracy: 0.8744 - 1s/epoch - 3ms/step
# Epoch 55/101
# 454/454 - 1s - loss: 0.2856 - accuracy: 0.8929 - val_loss: 0.3280 - val_accuracy: 0.8747 - 1s/epoch - 3ms/step
# Epoch 56/101
# 454/454 - 1s - loss: 0.2852 - accuracy: 0.8954 - val_loss: 0.3286 - val_accuracy: 0.8780 - 1s/epoch - 3ms/step
# Epoch 57/101
# 454/454 - 1s - loss: 0.2848 - accuracy: 0.8932 - val_loss: 0.3297 - val_accuracy: 0.8719 - 1s/epoch - 3ms/step
# Epoch 58/101
# 454/454 - 1s - loss: 0.2844 - accuracy: 0.8949 - val_loss: 0.3412 - val_accuracy: 0.8675 - 1s/epoch - 3ms/step
# Epoch 59/101
# 454/454 - 1s - loss: 0.2857 - accuracy: 0.8919 - val_loss: 0.3361 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 60/101
# 454/454 - 1s - loss: 0.2834 - accuracy: 0.8961 - val_loss: 0.3327 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 61/101
# 454/454 - 2s - loss: 0.2821 - accuracy: 0.8963 - val_loss: 0.3321 - val_accuracy: 0.8725 - 2s/epoch - 3ms/step
# Epoch 62/101
# 454/454 - 1s - loss: 0.2840 - accuracy: 0.8943 - val_loss: 0.3314 - val_accuracy: 0.8738 - 1s/epoch - 3ms/step
# Epoch 63/101
# 454/454 - 1s - loss: 0.2825 - accuracy: 0.8945 - val_loss: 0.3375 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 64/101
# 454/454 - 1s - loss: 0.2834 - accuracy: 0.8943 - val_loss: 0.3305 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 65/101
# 454/454 - 2s - loss: 0.2824 - accuracy: 0.8962 - val_loss: 0.3313 - val_accuracy: 0.8763 - 2s/epoch - 3ms/step
# Epoch 66/101
# 454/454 - 1s - loss: 0.2815 - accuracy: 0.8946 - val_loss: 0.3288 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 67/101
# 454/454 - 1s - loss: 0.2808 - accuracy: 0.8966 - val_loss: 0.3301 - val_accuracy: 0.8752 - 1s/epoch - 3ms/step
# Epoch 68/101
# 454/454 - 1s - loss: 0.2815 - accuracy: 0.8965 - val_loss: 0.3313 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 69/101
# 454/454 - 1s - loss: 0.2829 - accuracy: 0.8940 - val_loss: 0.3269 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 70/101
# 454/454 - 1s - loss: 0.2799 - accuracy: 0.8992 - val_loss: 0.3279 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 71/101
# 454/454 - 2s - loss: 0.2809 - accuracy: 0.8962 - val_loss: 0.3286 - val_accuracy: 0.8727 - 2s/epoch - 3ms/step
# Epoch 72/101
# 454/454 - 1s - loss: 0.2806 - accuracy: 0.8966 - val_loss: 0.3331 - val_accuracy: 0.8689 - 1s/epoch - 3ms/step
# Epoch 73/101
# 454/454 - 1s - loss: 0.2823 - accuracy: 0.8943 - val_loss: 0.3442 - val_accuracy: 0.8658 - 1s/epoch - 3ms/step
# Epoch 74/101
# 454/454 - 1s - loss: 0.2802 - accuracy: 0.8972 - val_loss: 0.3303 - val_accuracy: 0.8733 - 1s/epoch - 3ms/step
# Epoch 75/101
# 454/454 - 2s - loss: 0.2801 - accuracy: 0.8975 - val_loss: 0.3286 - val_accuracy: 0.8755 - 2s/epoch - 3ms/step
# Epoch 76/101
# 454/454 - 1s - loss: 0.2799 - accuracy: 0.8996 - val_loss: 0.3411 - val_accuracy: 0.8691 - 1s/epoch - 3ms/step
# Epoch 77/101
# 454/454 - 2s - loss: 0.2808 - accuracy: 0.8943 - val_loss: 0.3317 - val_accuracy: 0.8664 - 2s/epoch - 3ms/step
# Epoch 78/101
# 454/454 - 2s - loss: 0.2794 - accuracy: 0.8958 - val_loss: 0.3398 - val_accuracy: 0.8691 - 2s/epoch - 3ms/step
# Epoch 79/101
# 454/454 - 1s - loss: 0.2782 - accuracy: 0.8983 - val_loss: 0.3427 - val_accuracy: 0.8694 - 1s/epoch - 3ms/step
# Epoch 80/101
# 454/454 - 1s - loss: 0.2791 - accuracy: 0.8973 - val_loss: 0.3324 - val_accuracy: 0.8719 - 1s/epoch - 3ms/step
# Epoch 81/101
# 454/454 - 1s - loss: 0.2798 - accuracy: 0.8976 - val_loss: 0.3352 - val_accuracy: 0.8716 - 1s/epoch - 3ms/step
# Epoch 82/101
# 454/454 - 1s - loss: 0.2778 - accuracy: 0.8978 - val_loss: 0.3349 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 83/101
# 454/454 - 2s - loss: 0.2780 - accuracy: 0.8969 - val_loss: 0.3331 - val_accuracy: 0.8749 - 2s/epoch - 3ms/step
# Epoch 84/101
# 454/454 - 2s - loss: 0.2767 - accuracy: 0.9000 - val_loss: 0.3477 - val_accuracy: 0.8669 - 2s/epoch - 3ms/step
# Epoch 85/101
# 454/454 - 1s - loss: 0.2802 - accuracy: 0.8963 - val_loss: 0.3418 - val_accuracy: 0.8683 - 1s/epoch - 3ms/step
# Epoch 86/101
# 454/454 - 1s - loss: 0.2788 - accuracy: 0.8965 - val_loss: 0.3391 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 87/101
# 454/454 - 1s - loss: 0.2772 - accuracy: 0.8992 - val_loss: 0.3412 - val_accuracy: 0.8672 - 1s/epoch - 3ms/step
# Epoch 88/101
# 454/454 - 1s - loss: 0.2760 - accuracy: 0.8989 - val_loss: 0.3346 - val_accuracy: 0.8675 - 1s/epoch - 3ms/step
# Epoch 89/101
# 454/454 - 1s - loss: 0.2779 - accuracy: 0.8995 - val_loss: 0.3331 - val_accuracy: 0.8691 - 1s/epoch - 3ms/step
# Epoch 90/101
# 454/454 - 1s - loss: 0.2763 - accuracy: 0.8963 - val_loss: 0.3394 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 91/101
# 454/454 - 1s - loss: 0.2772 - accuracy: 0.8991 - val_loss: 0.3402 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 92/101
# 454/454 - 2s - loss: 0.2762 - accuracy: 0.8994 - val_loss: 0.3323 - val_accuracy: 0.8713 - 2s/epoch - 3ms/step
# Epoch 93/101
# 454/454 - 1s - loss: 0.2779 - accuracy: 0.8996 - val_loss: 0.3446 - val_accuracy: 0.8667 - 1s/epoch - 3ms/step
# Epoch 94/101
# 454/454 - 1s - loss: 0.2771 - accuracy: 0.8967 - val_loss: 0.3341 - val_accuracy: 0.8738 - 1s/epoch - 3ms/step
# Epoch 95/101
# 454/454 - 1s - loss: 0.2744 - accuracy: 0.8997 - val_loss: 0.3353 - val_accuracy: 0.8725 - 1s/epoch - 3ms/step
# Epoch 96/101
# 454/454 - 1s - loss: 0.2761 - accuracy: 0.8992 - val_loss: 0.3341 - val_accuracy: 0.8691 - 1s/epoch - 3ms/step
# Epoch 97/101
# 454/454 - 1s - loss: 0.2751 - accuracy: 0.8988 - val_loss: 0.3319 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 98/101
# 454/454 - 2s - loss: 0.2756 - accuracy: 0.8987 - val_loss: 0.3376 - val_accuracy: 0.8708 - 2s/epoch - 3ms/step
# Epoch 99/101
# 454/454 - 1s - loss: 0.2741 - accuracy: 0.9006 - val_loss: 0.3424 - val_accuracy: 0.8716 - 1s/epoch - 3ms/step
# Epoch 100/101
# 454/454 - 1s - loss: 0.2752 - accuracy: 0.9000 - val_loss: 0.3558 - val_accuracy: 0.8642 - 1s/epoch - 3ms/step
# Epoch 101/101
# 454/454 - 2s - loss: 0.2734 - accuracy: 0.8994 - val_loss: 0.3427 - val_accuracy: 0.8705 - 2s/epoch - 3ms/step

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.656113  0.757112  0.506683      0.840220
# 1  0.462740  0.853482  0.427441      0.868320
# 2  0.400138  0.871048  0.386296      0.867769
# 3  0.368010  0.877592  0.366022      0.871625
# 4  0.349580  0.880141  0.358198      0.864738

# %%
fn_plot_tf_hist(loss_df)
